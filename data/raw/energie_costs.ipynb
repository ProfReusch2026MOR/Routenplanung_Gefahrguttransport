# %%
import pandas as pd

energy_prices = {
    "depot": 0.35,        # zuhause / Depot
    "urban_ac": 0.55,     # Stadt AC
    "urban_dc": 0.60,     # Stadt Schnell
    "highway_hpc": 0.75   # Autobahn Schnellladen
}

# %%
df = pd.DataFrame(
    list(energy_prices.items()),
    columns=["scenario", "price_eur_per_kwh"]
)

# %%
df.to_csv("../processed/energy_prices.csv", index=False)
