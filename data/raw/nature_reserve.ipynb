# %%
import pandas as pd
import geopandas as gpd
import numpy as np

# %%
pip install geopandas
# Out:
# ...
#
# ...

# %%
import geopandas as gpd

url = "https://geodienste.bfn.de/ogc/wfs/schutzgebiet"

gdf = gpd.read_file(
    url,
    layer="Naturschutzgebiete",
    rows=slice(None)
)
gdf = gdf.to_crs(epsg=4326)

# %%
gdf_filtered = gdf[
    gdf["BL"].isin(["NW", "NI"])
]

# %%
gdf_filtered.to_csv("../processed/nature_reserves_filtered.csv",
                index=False,
                encoding="utf-8")
